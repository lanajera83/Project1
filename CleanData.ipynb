# %%
#import variables and read cvs
import pandas as pd
import numpy as np
file = "listings_mexico.csv"
df = pd.read_csv(file, encoding="ISO-8859-1")
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=106)

# %%
#reduce table for usefull columns
table_df = df.loc[:, ["id", "name", "host_id", "host_name", "neighbourhood_cleansed", "neighbourhood", "latitude", "longitude","room_type", "price", "minimum_nights", "number_of_reviews", "last_review", "reviews_per_month", "calculated_host_listings_count", "availability_365", "bed_type", "amenities", "review_scores_rating"]]
table_df.head()
# Out:
#       id                                               name  host_id  \
# 0  14714         Private room c/ bathroom . Colonia Juarez.    57785
# 1  22787  Sunny suite w/ queen size bed, inside boutique...    87973
# 2  33681                                    Couple of Rooms   145672
# 3  35797                                        Villa Dante   153786
# 4  44616                          CONDESA HAUS BOUTIQUE B&B   196253
#
#                             host_name neighbourhood_cleansed neighbourhood  \
# 0                               Diego            CuauhtÃ©moc       JuÃ¡rez
# 1                               Diego            CuauhtÃ©moc    San Rafael
# 2                             Edubiel                Tlalpan           NaN
# 3                                Dici  Cuajimalpa de Morelos           NaN
# 4  Condesa Haus Bed & BReakfast  CDMX            CuauhtÃ©moc       Condesa
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
#Check data types
table_df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_cleansed             object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# bed_type                           object
# amenities                          object
# review_scores_rating              float64
# dtype: object

# %%
#Review odd characters
listado = table_df["neighbourhood_cleansed"].unique()
listado1 = listado.tolist()
listado1
# Out:
# ['CuauhtÃ©moc',
#  'Tlalpan',
#  'Cuajimalpa de Morelos',
#  'CoyoacÃ¡n',
#  'Miguel Hidalgo',
#  'Benito JuÃ¡rez',
#  'Azcapotzalco',
#  'Iztacalco',
#  'Venustiano Carranza',
#  'Ã\x81lvaro ObregÃ³n',
#  'Iztapalapa',
#  'Gustavo A. Madero',
#  'Xochimilco',
#  'La Magdalena Contreras',
#  'TlÃ¡huac',
#  'Milpa Alta']

# %%
number_of_b= len(listado1)
number_of_b
# Out:
# 16

# %%
#Filter database to keep number of reviews higher than 1
#Clean odd characters
table_reviews = table_df.loc[table_df["number_of_reviews"]>=0, ["id", "name", "host_id", "host_name", "neighbourhood_cleansed", "neighbourhood", "latitude", "longitude","room_type", "price", "minimum_nights", "number_of_reviews", "last_review", "reviews_per_month", "calculated_host_listings_count", "availability_365", "bed_type", "amenities", "review_scores_rating"]]
table_reviews['neighbourhood_cleansed'] = table_reviews['neighbourhood_cleansed'].str.replace('Ã©', 'e')
table_reviews['neighbourhood_cleansed'] = table_reviews['neighbourhood_cleansed'].str.replace('Ã¡', 'a')
table_reviews['neighbourhood_cleansed'] = table_reviews['neighbourhood_cleansed'].str.replace('Ã', 'A')
table_reviews['neighbourhood_cleansed'] = table_reviews['neighbourhood_cleansed'].str.replace('Ã³', 'o')

table_reviews['neighbourhood'] = table_reviews['neighbourhood'].str.replace('Ã©', 'e')
table_reviews['neighbourhood'] = table_reviews['neighbourhood'].str.replace('Ã¡', 'a')
table_reviews['neighbourhood'] = table_reviews['neighbourhood'].str.replace('Ã', 'A')
table_reviews['neighbourhood'] = table_reviews['neighbourhood'].str.replace('Ã³', 'o')
table_reviews.head()
# Out:
#       id                                               name  host_id  \
# 0  14714         Private room c/ bathroom . Colonia Juarez.    57785
# 1  22787  Sunny suite w/ queen size bed, inside boutique...    87973
# 2  33681                                    Couple of Rooms   145672
# 3  35797                                        Villa Dante   153786
# 4  44616                          CONDESA HAUS BOUTIQUE B&B   196253
#
#                             host_name neighbourhood_cleansed neighbourhood  \
# 0                               Diego             Cuauhtemoc        Juarez
# 1                               Diego             Cuauhtemoc    San Rafael
# 2                             Edubiel                Tlalpan           NaN
# 3                                Dici  Cuajimalpa de Morelos           NaN
# 4  Condesa Haus Bed & BReakfast  CDMX             Cuauhtemoc       Condesa
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
table_reviews.to_csv("data_base_clean.csv", index=False)
